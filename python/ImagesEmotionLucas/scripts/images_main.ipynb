# %% [markdown]
# ### Pruebas con:
# #### 1) Una imagen
# #### 2) Carpeta con imágenes
# #### 3) Vídeo

# %%
from frames_processing import ProcessFrame

# %%
fpath = '../test_images/lucas/WIN_20221129_14_17_56_Pro.jpg'

ProcessFrame(fpath)
# Out:
# ../test_images/lucas/WIN_20221129_14_17_56_Pro.jpg
# env: CUDA_VISIBLE_DEVICES=0
# Cuda:  False
# Score cara 1:  [-0.6525233  -2.3914988   2.8448646  -2.5433028  -0.22701989 -0.9957334
#   1.9221305 ]

# %%
fpath = '../test_images/sample_input'

ProcessFrame(fpath, want_plot = True)
# Out:
# ../test_images/sample_input
# env: CUDA_VISIBLE_DEVICES=0
# Cuda:  False
# 0 ../test_images/sample_input/0.png
# Score cara 1:  [-2.3918588  -0.7705082   1.0003706  -0.29448396  0.21020898  1.00688
#   0.22539312]
# 1 ../test_images/sample_input/1.png
# Score cara 1:  [-2.3629484  -1.305147   -0.71316564  2.216139    1.4827709   1.8581376
#  -0.59137785]
# 2 ../test_images/sample_input/10.png
# Score cara 1:  [ 1.0269396  -0.43470955 -2.3007863  -0.51764995  2.4525497   1.4134732
#  -0.7716547 ]
# 3 ../test_images/sample_input/11.png
# Score cara 1:  [-0.45540962 -0.873177   -1.5476182   0.5084739   1.3065003  -0.41356304
#   1.5251893 ]
# 4 ../test_images/sample_input/12.png
# Score cara 1:  [-1.4223888   0.7034429   1.0437008   0.4873521  -2.1751988   0.70165277
#  -0.8849335 ]
# 5 ../test_images/sample_input/13.png
# Score cara 1:  [-2.6721327  -0.63971806  1.3411645   1.3248018  -1.5196699   2.2176254
#  -0.718952  ]
# 6 ../test_images/sample_input/14.png
# Score cara 1:  [-0.71096516  1.9140848  -1.1966808   1.4715157  -1.5654353   1.3551462
#  -1.3145689 ]
# 7 ../test_images/sample_input/2.png
# Score cara 1:  [-2.704695   -2.045339    0.71060157  2.5903873  -0.532474    0.08730732
#   1.3412321 ]
# 8 ../test_images/sample_input/3.png
# Score cara 1:  [ 0.6173792   2.5789027  -3.5281754   1.6190399   1.3225867  -0.39263695
#  -1.5847838 ]
# 9 ../test_images/sample_input/4.png
# Score cara 1:  [-2.5200257  -2.8274648   0.51904863  2.85276     1.3881149   1.8091891
#   0.281006  ]
# 10 ../test_images/sample_input/5.png
# Score cara 1:  [-1.7167346  -0.8933776  -1.166748    1.2058939   1.794806    1.5782768
#  -0.14704925]
# 11 ../test_images/sample_input/6.png
# Score cara 1:  [-3.2664857  -1.4973068   0.84458524  4.427252   -1.4990119   0.36106762
#   1.0358719 ]
# 12 ../test_images/sample_input/7.png
# Score cara 1:  [-2.7996924  -1.1189312  -1.5020982   6.457969    0.82847077 -0.701302
#   1.1030923 ]
# 13 ../test_images/sample_input/8.png
# Score cara 1:  [-3.2715428  -3.1373525   1.0412099   5.195688   -0.36814603  2.2201562
#   0.13178521]
# 14 ../test_images/sample_input/9.png
# Score cara 1:  [-1.4024893  -2.0296412  -0.00576691  2.98285     2.102395   -1.2852576
#   0.8747935 ]

# %%
fpath = '../test_images/WIN_20221201_19_23_14_Pro.mp4'

ProcessFrame(fpath, want_plot=True)
# Out:
# ../test_images/WIN_20221201_19_23_14_Pro.mp4
# frames per second = 29.833423850371616
# env: CUDA_VISIBLE_DEVICES=0
# Cuda:  False
# Score cara 1:  [ 0.1893682 -3.7024994 -2.8133366  3.4325774  4.88117    2.219281
#  -0.7490442]
# Score cara 1:  [ 0.6584619 -2.5713727 -1.3481145 38.15029   13.446597   6.225959
#  16.34897  ]
# Score cara 1:  [-0.06245542 -0.17497906 -2.3553476   0.8759059   2.552573    2.6043992
#  -1.8705957 ]
# Score cara 1:  [-1.469076   -1.8832248   0.5420539  -1.6181282   1.345765    3.5193028
#  -0.41857433]
# Score cara 1:  [-2.6935585 -2.9771798  3.6646447 -1.6465265 -0.6480957 -1.5831865
#   3.6550515]
# Score cara 1:  [-2.648204  -2.5132523  3.703223  -1.6879193 -1.0419062 -1.7665997
#   3.6109416]
# Score cara 1:  [-1.1840136  -1.9716544   1.6462231  -2.7207162   0.89599967  2.0858188
#   0.1401499 ]
# Score cara 1:  [ 3.4492736  0.7227188 -0.953903  -3.2194026  0.2887376  2.045443
#  -3.2695484]
# Score cara 1:  [ 1.8387862  -1.5912516   0.12208307 -2.702864    1.7852702   2.7389963
#  -2.3704133 ]
# Score cara 1:  [ 0.08116768 -2.899842   -1.6519812   0.5760461   3.7859573   3.743008
#  -1.4971824 ]
# Score cara 1:  [ 3.4567788   1.9808531  -2.7694035  -1.2981097   0.67896414  0.91478205
#  -3.2868333 ]
# Score cara 1:  [  6.6835747   2.3908217 -10.498075   31.039892   15.577408   10.369092
#    2.672316 ]
# Score cara 1:  [ 0.48770404 -1.0426859  -5.1058393  10.509653    3.3389318   1.9720107
#  -1.4281411 ]
# Score cara 1:  [-0.28835437 -0.45538348 -4.144795    5.513182    3.1637743   1.6671994
#  -2.0505147 ]
# There is no image!
